# %%
from game_setup import *

# %%
player1 = Player("Yoav")
player2 = Player("Rani")

game = Game([player1, player2], 
            ['chance_cards.csv', 'community_chest_cards.csv'], 
            'squares.csv')

# %%
game.run_game(10000)

# %%
game.extract_results()
game.results_plot
# Out:
# <AxesSubplot:xlabel='type,sequence'>

# %%
game.results['share_of_visits'].plot(kind='bar', x=game.results['type'])
# Out:
# <AxesSubplot:>

# %%
game.results
# Out:
#     purchasable          type         sequence             name  visits_count  \
# 0         False            Go               Go               Go           455
# 1          True      Property           Purple          Purple1           468
# 2         False          Card  Community Chest  Community Chest           513
# 3          True      Property           Purple          Purple2           483
# 4         False           Tax         City Tax         City tax           525
# 5          True         Train            Train           Train1           488
# 6          True      Property        LightBlue       LightBlue1           494
# 7         False          Card           Chance           Chance           512
# 8          True      Property        LightBlue       LightBlue2           469
# 9          True      Property        LightBlue       LightBlue3           471
# 10        False          Jail             Jail             Jail           477
# 11         True      Property             Pink            Pink1           496
# 12         True       Utility          Utility         Utility1           468
# 13         True      Property             Pink            Pink2           529
# 14         True      Property             Pink            Pink3           532
# 15         True         Train            Train           Train2           541
# 16         True      Property           Orange          Orange1           529
# 17        False          Card  Community Chest  Community Chest           546
# 18         True      Property           Orange          Orange2           532
# 19         True      Property           Orange          Orange3           545
# 20        False  Free Parking     Free Parking     Free Parking           536
# 21         True      Property              Red             Red1           504
# 22        False          Card           Chance           Chance           468
# 23         True      Property              Red             Red2           458
# 24         True      Property              Red             Red3           514
# 25         True         Train            Train           Train3           473
# 26         True      Property           Yellow          Yellow1           472
# 27         True      Property           Yellow          Yellow2           534
# 28         True       Utility          Utility         Utility2           484
# 29         True      Property           Yellow          Yellow3           515
# 30        False    Go to jail       Go to jail       Go to jail           507
# 31         True      Property            Green           Green1           486
# 32         True      Property            Green           Green2           513
# 33        False          Card  Community Chest  Community Chest           529
# 34         True      Property            Green           Green3           515
# 35         True         Train            Train           Train4           527
# 36        False          Card           Chance           Chance           471
# 37         True      Property         DarkBlue        DarkBlue1           513
# 38        False           Tax              Tax              Tax           442
# 39         True      Property         DarkBlue        DarkBlue2           467
#
#     share_of_visits
# 0          0.022749
# 1          0.023399
# 2          0.025649
# 3          0.024149
# 4          0.026249
# 5          0.024399
# 6          0.024699
# 7          0.025599
# 8          0.023449
# 9          0.023549
# 10         0.023849
# 11         0.024799
# 12         0.023399
# 13         0.026449
# 14         0.026599
# 15         0.027049
# 16         0.026449
# 17         0.027299
# 18         0.026599
# 19         0.027249
# 20         0.026799
# 21         0.025199
# 22         0.023399
# 23         0.022899
# 24         0.025699
# 25         0.023649
# 26         0.023599
# 27         0.026699
# 28         0.024199
# 29         0.025749
# 30         0.025349
# 31         0.024299
# 32         0.025649
# 33         0.026449
# 34         0.025749
# 35         0.026349
# 36         0.023549
# 37         0.025649
# 38         0.022099
# 39         0.023349
